# %%
def crear_tablero(fila_gato, columna_gato, fila_raton, columna_raton,fila, columna):
    tablero = [["."for _ in range(fila)]for _ in range(columna)]

    tablero[fila_gato][columna_gato] = "G"
    tablero[fila_raton][columna_raton] = "R"

    for fila in tablero:
        print(" ".join(fila))

# %%
def crear_ciudad(fila_entrada, columna_entrada, fila_salida, columna_salida, fila_edificio, columna_edificio, fila_agua, columna_agua):
    ciudad = [["|.|"for _ in range(Filas)]for _ in range(columnas)]
    #posicionamos en la matriz 
    ciudad[fila_entrada][columna_entrada] = "E"
    ciudad[fila_salida][columna_salida] = "S"
    ciudad[fila_edificio][columna_edificio] = "#"
    ciudad[fila_agua][columna_agua] = "A"

    for filas in ciudad:
        print(" ".join(filas))

# %%
def inicio_juego():
    # configuraciones de inicio de juego (parametros)
    limite_movimientos = 20
    tamaño = int(input("Dime el tamaño del tablero que deseas: "))
    posicion_obstaculo = (tamaño - 3, tamaño - 3) 
    posicion_gato = (tamaño - 1, tamaño - 1)
    posicion_raton = (0, 0)

# %%
def iniciar_gps():
    dimension = int(input("Dime la cantidad de cuadras que deseas: "))

# %%
def obtener_movimientos_validos(fila_entrada, columna_entrada, fila_salida, columna_salida, fila_edificio, columna_edificio, fila_agua, columna_agua, dimension):
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    fila, columna = posicion_actual
    movimientos_validos = []
    
    for direccion in direcciones:
        nueva_fila = fila + direccion[0]
        nueva_columna = columna + direccion[1]
        
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if (nueva_fila, nueva_columna) not in posicion_obstaculo:
                movimientos_validos.append((nueva_fila, nueva_columna))
                
    return movimientos_validos

# %%
print("bienvenido al gps nivel 1 ")
print("Solo puedes meter numeros como datos")
dimension = int(input("Dime las cantidades de cuadras que quieres"))
fila_entrada = int(input("Dime la fila del punto de partida"))
columna_entrada = int(input("Dime la columna del punto de partida"))
entrada = (fila_entrada, columna_entrada)
fila_salida = int(input("Dime la fila del punto de llegada"))
columna_salida = int(input("Dime la columna del punto de llegada"))
salida = (fila_salida, columna_salida)
edificio = [(1, 1), (4, 4), (5, 6)]
agua = [(2, 2), (3, 3)]

while True:
    obstaculo_opcional = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
    if obstaculo_opcional == 1:
        fila = int(input("Dime la fila del obstaculo"))
        columna = int(input("Dime la columna del obstaculo"))
        obstaculo_opcional[fila][columna]
    elif obstaculo_opcional == 2:
        print("Queda sin obstaculos añadidos")
        break
    else:
        print("Opcion no valida favor lea las opciones e ingrese el numero")

def crear_ciudad(posicion_entrada, posicion_salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    ciudad = [["|.|"for _ in range(dimension)]for _ in range(dimension)]
    ciudad[posicion_entrada[0]][posicion_entrada[1]] = "E"
    ciudad[posicion_salida[0]][posicion_salida[1]] = "S"
    ciudad[posicion_edificio[0]][posicion_edificio[1]] = "#"
    ciudad[posicion_agua[0]][posicion_agua[1]] = "~"
    ciudad[posicion_obstaculo_opcional[0]][posicion_obstaculo_opcional[1]] = "!"

    for dimension in ciudad:
        print(" ".join(dimension))

crear_ciudad(entrada, salida, edificio, agua, obstaculo_opcional, dimension)
# Out:
# bienvenido al gps nivel 1
# Solo puedes meter numeros como datos
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 18
#      16     fila = int(input("Dime la fila del obstaculo"))
#      17     columna = int(input("Dime la columna del obstaculo"))
# ---> 18     obstaculo_opcional[fila][columna]
#      19 elif obstaculo_opcional == 2:
#      20     print("Queda sin obstaculos añadidos")
#
# TypeError: 'int' object is not subscriptable

# %%
print("bienvenido al gps nivel 1 ")
print("Solo puedes meter numeros como datos")
dimension = int(input("Dime las cantidades de cuadras que quieres"))
fila_entrada = int(input("Dime la fila del punto de partida"))
columna_entrada = int(input("Dime la columna del punto de partida"))
entrada = (fila_entrada, columna_entrada)
fila_salida = int(input("Dime la fila del punto de llegada"))
columna_salida = int(input("Dime la columna del punto de llegada"))
salida = (fila_salida, columna_salida)
edificio = [(1, 1), (4, 4), (5, 6)]
agua = [(2, 2), (3, 3)]
obstaculo_opcional = []

while True:
    obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
    if obstaculo == 1:
        fila = int(input("Dime la fila del obstaculo"))
        columna = int(input("Dime la columna del obstaculo"))
        obstaculo_agregado = (fila, columna)

        if obstaculo_agregado == entrada or obstaculo_agregado == salida:
            print("No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada")
        elif obstaculo_agregado == edificio:
            print("No se puede agregar aqui ya que es un Edificio")
        elif obstaculo_agregado == agua:
            print("No se puede agregar aqui ya que es un Rio")
        elif obstaculo_agregado == obstaculo_opcional:
            print("Aqui ya agregaste un obstaculo!!!")
        else:
            obstaculo_opcional.append(obstaculo_agregado)
    elif obstaculo == 2:
        break
    else:
        print("Opcion no valida favor lea las opciones e ingrese el numero")

def crear_ciudad(posicion_entrada, posicion_salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    ciudad = [["|.|"for _ in range(dimension)]for _ in range(dimension)]
    ciudad[posicion_entrada[0]][posicion_entrada[1]] = "|E|"
    ciudad[posicion_salida[0]][posicion_salida[1]] = "|S|"

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "|#|"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "|~|"

    for (fila, columna) in posicion_obstaculo_opcional:
        ciudad[fila][columna] = "|!|"

    for dimension in ciudad:
        print(" ".join(dimension))

def movimientos_validos(posicion_entrada, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    fila_entrada, columna_entrada = posicion_entrada
    edificio[0], edificio[1] = posicion_edificio
    agua[0], agua[1] = posicion_agua
    obstaculo_opcional[0], obstaculo_opcional[1] = posicion_obstaculo_opcional
    movimientos_validos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila_entrada + direccion[0]
        nueva_columna = columna_entrada + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if(nueva_fila, nueva_columna) not in posicion_edificio:
                if(nueva_fila, nueva_columna) not in posicion_agua:
                    if(nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos_validos.append((nueva_fila, nueva_columna))
    return movimientos_validos



crear_ciudad(entrada, salida, edificio, agua, obstaculo_opcional, dimension)

# %%
#validacion de los movimientos en el juego
def obtener_movimientos_validos(posicion_actual, posicion_obstaculo, tamaño):
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    fila, columna = posicion_actual
    movimientos_validos = []
    
    for direccion in direcciones:
        nueva_fila = fila + direccion[0]
        nueva_columna = columna + direccion[1]
        
        if 0 <= nueva_fila < tamaño and 0 <= nueva_columna < tamaño:
            if (nueva_fila, nueva_columna) not in posicion_obstaculo:
                movimientos_validos.append((nueva_fila, nueva_columna))
                
    return movimientos_validos

# %%
print("bienvenido al gps nivel 1 ")
print("Solo puedes meter numeros como datos")
dimension = int(input("Dime las cantidades de cuadras que quieres"))
fila_entrada = int(input("Dime la fila del punto de partida"))
columna_entrada = int(input("Dime la columna del punto de partida"))
entrada = (fila_entrada, columna_entrada)
fila_salida = int(input("Dime la fila del punto de llegada"))
columna_salida = int(input("Dime la columna del punto de llegada"))
salida = (fila_salida, columna_salida)
edificio = [(1, 1), (4, 4), (5, 6)]
agua = [(2, 2), (3, 3)]
obstaculo_opcional = []

while True:
    obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
    if obstaculo == 1:
        fila = int(input("Dime la fila del obstaculo"))
        columna = int(input("Dime la columna del obstaculo"))
        obstaculo_agregado = (fila, columna)

        if obstaculo_agregado == entrada or obstaculo_agregado == salida:
            print("No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada")
        elif obstaculo_agregado == edificio:
            print("No se puede agregar aqui ya que es un Edificio")
        elif obstaculo_agregado == agua:
            print("No se puede agregar aqui ya que es un Rio")
        elif obstaculo_agregado == obstaculo_opcional:
            print("Aqui ya agregaste un obstaculo!!!")
        else:
            obstaculo_opcional.append(obstaculo_agregado)
    elif obstaculo == 2:
        break
    else:
        print("Opcion no valida favor lea las opciones e ingrese el numero")

def crear_ciudad(posicion_entrada, posicion_salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    ciudad = [["|.|"for _ in range(dimension)]for _ in range(dimension)]
    ciudad[posicion_entrada[0]][posicion_entrada[1]] = "|E|"
    ciudad[posicion_salida[0]][posicion_salida[1]] = "|S|"

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "|#|"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "|~|"

    for (fila, columna) in posicion_obstaculo_opcional:
        ciudad[fila][columna] = "|!|"

    for dimension in ciudad:
        print(" ".join(dimension))

def movimientos_validos(posicion_entrada, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    fila_entrada, columna_entrada = posicion_entrada
    movimientos_validos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila_entrada + direccion[0]
        nueva_columna = columna_entrada + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if(nueva_fila, nueva_columna) not in posicion_edificio:
                if(nueva_fila, nueva_columna) not in posicion_agua:
                    if(nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos_validos.append((nueva_fila, nueva_columna))
    return movimientos_validos



crear_ciudad(entrada, salida, edificio, agua, obstaculo_opcional, dimension)

# %%
print("Bienvenido al gps nivel 1 ")
print("Solo puedes meter numeros como datos")
dimension = int(input("Dime las cantidades de cuadras que quieres"))
edificio = [(1, 1), (4, 4), (5, 6)]
agua = [(2, 2), (3, 3)]


while True:
    fila_entrada = int(input("Dime la fila del punto de partida"))
    columna_entrada = int(input("Dime la columna del punto de partida"))
    entrada = (fila_entrada, columna_entrada)

    if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
        print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
    elif entrada in edificio:
        print(f"Aqui hay un edificio {fila_entrada, columna_entrada}")
    elif entrada in agua:
        print(f"Aqui hay un rio {fila_entrada, columna_entrada}")
    else:
        print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
        break

while True:
    fila_salida = int(input("Dime la fila del punto de llegada"))
    columna_salida = int(input("Dime la columna del punto de llegada"))
    salida = (fila_salida, columna_salida)

    if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
        print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
    elif salida in edificio:
        print(f"Aqui hay un edificio {fila_salida, columna_salida}")
    elif salida in agua:
        print(f"Aqui hay un rio {fila_salida, columna_salida}")
    elif salida == entrada:
        print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
    else:
        print(f"Colocaste la salida en {fila_salida, columna_salida}")
        break


obstaculo_opcional = []
while True:
    obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
    if obstaculo == 1:
        fila = int(input("Dime la fila del obstaculo"))
        columna = int(input("Dime la columna del obstaculo"))
        obstaculo_agregado = (fila, columna)

        if not (0 <= fila < dimension and 0 <= columna < dimension):
            print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
        elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
            print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
        elif obstaculo_agregado in edificio:
            print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
        elif obstaculo_agregado in agua:
            print(f"No se puede agregar aqui ya que es un Rio {fila, columna}")
        elif obstaculo_agregado in obstaculo_opcional:
            print(f"Aqui ya agregaste un obstaculo!!!{fila, columna}")
        else:
            obstaculo_opcional.append(obstaculo_agregado)
            print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
    elif obstaculo == 2:
        break
    else:
        print("Opcion no valida favor lea las opciones e ingrese el numero")

# funcion para crear y posicionar los elementos dentro de la matrriz 
def crear_ciudad(posicion_entrada, posicion_salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    ciudad = [["|.|"for _ in range(dimension)]for _ in range(dimension)]
    ciudad[posicion_entrada[0]][posicion_entrada[1]] = "|E|"
    ciudad[posicion_salida[0]][posicion_salida[1]] = "|S|"

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "|#|"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "|~|"

    for (fila, columna) in posicion_obstaculo_opcional:
        ciudad[fila][columna] = "|!|"

    for dimension in ciudad:
        print(" ".join(dimension))


# movimientos validos que puede realizar dentro del gps
def movimientos_validos(posicion_entrada, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    fila_entrada, columna_entrada = posicion_entrada
    movimientos_validos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila_entrada + direccion[0]
        nueva_columna = columna_entrada + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if(nueva_fila, nueva_columna) not in posicion_edificio:
                if(nueva_fila, nueva_columna) not in posicion_agua:
                    if(nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos_validos.append((nueva_fila, nueva_columna))
    return movimientos_validos


crear_ciudad(entrada, salida, edificio, agua, obstaculo_opcional, dimension)
# Out:
# Bienvenido al gps nivel 1
# Solo puedes meter numeros como datos
# Aqui hay un rio (2, 2)
# Aqui hay un rio (3, 3)
# Este punto esta fuera de los limites de la ciudad (1, 12)
# Aqui hay un edificio (1, 1)
# Colocaste la entrada en (0, 0)
# Colocaste la salida en (8, 8)
# Agregaste un obstaculo temporal en la posicion (9, 9)
# |E| |.| |.| |.| |.| |.| |.| |.| |.| |.|
# |.| |#| |.| |.| |.| |.| |.| |.| |.| |.|
# |.| |.| |~| |.| |.| |.| |.| |.| |.| |.|
# |.| |.| |.| |~| |.| |.| |.| |.| |.| |.|
# |.| |.| |.| |.| |#| |.| |.| |.| |.| |.|
# |.| |.| |.| |.| |.| |.| |#| |.| |.| |.|
# |.| |.| |.| |.| |.| |.| |.| |.| |.| |.|
# |.| |.| |.| |.| |.| |.| |.| |.| |.| |.|
# |.| |.| |.| |.| |.| |.| |.| |.| |S| |.|
# |.| |.| |.| |.| |.| |.| |.| |.| |.| |!|

# %%
import random

# ==========================
# 1️⃣ ENTRADA DE DATOS
# ==========================
print("🌍 Bienvenido al GPS Nivel 2 - Mapa Aleatorio 🌍")
dimension = int(input("Dime la cantidad de cuadras que quieres: "))

# ==========================
# 2️⃣ GENERAR MAPA ALEATORIO
# ==========================
# Porcentaje de elementos en el mapa
PROB_EDIFICIO = 35  # 15%
PROB_AGUA = 15      # 10%

ciudad = []
edificios = []
aguas = []
for fila in range(dimension):
    ciudad.append([])
    for columna in range(dimension):
        rand_num = random.randint(0, 100)

        if rand_num < PROB_EDIFICIO:
            ciudad[fila].append("|#|")    # Edificio
            edificios.append((fila, columna))
        elif rand_num < PROB_EDIFICIO + PROB_AGUA:
            ciudad[fila].append("|~|")    # Agua
            aguas.append((fila, columna))
        else:
            ciudad[fila].append("|.|")    # Camino libre

# ==========================
# 3️⃣ MOSTRAR MAPA GENERADO
# ==========================
print("\n📍 MAPA GENERADO:\n")
for fila in ciudad:
    print(" ".join(fila))

# ==========================
# 4️⃣ PEDIR ENTRADA y SALIDA
# ==========================
while True:
    fila_entrada = int(input("\nDime la fila del punto de PARTIDA: "))
    columna_entrada = int(input("Dime la columna del punto de PARTIDA: "))
    entrada = (fila_entrada, columna_entrada)

    if entrada in edificios:
        print("❌ No puedes poner la ENTRADA en un edificio.")
    elif entrada in aguas:
        print("❌ No puedes poner la ENTRADA en un río.")
    else:
        break

while True:
    fila_salida = int(input("\nDime la fila del punto de LLEGADA: "))
    columna_salida = int(input("Dime la columna del punto de LLEGADA: "))
    salida = (fila_salida, columna_salida)

    if salida in edificios:
        print("❌ No puedes poner la SALIDA en un edificio.")
    elif salida in aguas:
        print("❌ No puedes poner la SALIDA en un río.")
    else:
        break

# ==========================
# 5️⃣ OBSTÁCULOS OPCIONALES
# ==========================
obstaculos = []
while True:
    opcion = int(input("\n1- Ingresar un obstáculo opcional | 2- No añadir más obstáculos: "))
    if opcion == 1:
        fila_obs = int(input("Dime la fila del obstáculo: "))
        columna_obs = int(input("Dime la columna del obstáculo: "))
        nuevo_obs = (fila_obs, columna_obs)

        if nuevo_obs == entrada or nuevo_obs == salida:
            print("❌ No se puede colocar un obstáculo en ENTRADA o SALIDA.")
        elif nuevo_obs in edificios:
            print("❌ No se puede colocar un obstáculo en un edificio.")
        elif nuevo_obs in aguas:
            print("❌ No se puede colocar un obstáculo en un río.")
        elif nuevo_obs in obstaculos:
            print("❌ Ya existe un obstáculo en esta posición.")
        else:
            obstaculos.append(nuevo_obs)
    elif opcion == 2:
        break
    else:
        print("❌ Opción no válida, intenta de nuevo.")

# ==========================
# 6️⃣ CREAR MAPA FINAL
# ==========================
# Limpiar mapa para representar ENTRADA, SALIDA y OBSTÁCULOS
ciudad[entrada[0]][entrada[1]] = "|E|"
ciudad[salida[0]][salida[1]] = "|S|"

for (fila, columna) in obstaculos:
    ciudad[fila][columna] = "|!|"

# ==========================
# 7️⃣ MOSTRAR MAPA FINAL
# ==========================
print("\n🌍 MAPA FINAL LISTO PARA NAVEGAR:\n")
for fila in ciudad:
    print(" ".join(fila))
# Out:
# 🌍 Bienvenido al GPS Nivel 2 - Mapa Aleatorio 🌍
# 📍 MAPA GENERADO:
#
# |.| |#| |.| |#| |.| |#| |.| |.| |#| |.|
# |.| |#| |.| |.| |#| |.| |~| |.| |.| |#|
# |#| |#| |~| |#| |~| |.| |.| |.| |#| |~|
# |.| |#| |.| |~| |#| |#| |~| |#| |#| |#|
# |#| |.| |#| |#| |.| |#| |#| |#| |.| |.|
# |.| |~| |.| |.| |#| |#| |#| |.| |.| |.|
# |.| |.| |#| |#| |.| |.| |#| |.| |#| |~|
# |#| |#| |.| |~| |.| |.| |~| |.| |.| |.|
# |#| |.| |~| |~| |.| |.| |#| |.| |#| |.|
# |.| |.| |.| |.| |#| |.| |.| |~| |.| |.|
#
# 🌍 MAPA FINAL LISTO PARA NAVEGAR:
#
# |E| |#| |.| |#| |.| |#| |.| |.| |#| |.|
# |.| |#| |.| |.| |#| |.| |~| |.| |.| |#|
# |#| |#| |~| |#| |~| |.| |.| |.| |#| |~|
# |.| |#| |.| |~| |#| |#| |~| |#| |#| |#|
# |#| |.| |#| |#| |.| |#| |#| |#| |.| |.|
# |.| |~| |.| |.| |#| |#| |#| |.| |.| |.|
# |.| |.| |#| |#| |.| |.| |#| |.| |#| |~|
# |#| |#| |.| |~| |.| |.| |~| |.| |.| |.|
# |#| |.| |~| |~| |.| |.| |#| |.| |#| |.|
# |.| |.| |.| |.| |#| |.| |.| |~| |.| |S|

# %%
def crear_ciudad(posicion_entrada, posicion_salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    ciudad = [["."for _ in range(dimension)]for _ in range(dimension)]
    ciudad[posicion_entrada[0]][posicion_entrada[1]] = "E"
    ciudad[posicion_salida[0]][posicion_salida[1]] = "S"

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "#"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "~"

    for (fila, columna) in posicion_obstaculo_opcional:
        ciudad[fila][columna] = "!"

    for filas in ciudad:
        print(" ".join(filas))


# movimientos validos que puede realizar dentro del gps
def movimientos_validos(posicion_entrada, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    fila_entrada, columna_entrada = posicion_entrada
    movimientos_validos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila_entrada + direccion[0]
        nueva_columna = columna_entrada + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if(nueva_fila, nueva_columna) not in posicion_edificio:
                if(nueva_fila, nueva_columna) not in posicion_agua:
                    if(nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos_validos.append((nueva_fila, nueva_columna))
    return movimientos_validos


# configuracion inicial de los parametros del gps 
def inicio_gps():
    dimension = int(input("Dime las cantidades de cuadras que quieres"))
    edificio = [(1, 1), (4, 4), (5, 6)]
    agua = [(2, 2), (3, 3)]


    while True:
        fila_entrada = int(input("Dime la fila del punto de partida"))
        columna_entrada = int(input("Dime la columna del punto de partida"))
        entrada = (fila_entrada, columna_entrada)

        if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
        elif entrada in edificio:
            print(f"Aqui hay un edificio {fila_entrada, columna_entrada}")
        elif entrada in agua:
            print(f"Aqui hay un rio {fila_entrada, columna_entrada}")
        else:
            print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
            break

    while True:
        fila_salida = int(input("Dime la fila del punto de llegada"))
        columna_salida = int(input("Dime la columna del punto de llegada"))
        salida = (fila_salida, columna_salida)

        if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
        elif salida in edificio:
            print(f"Aqui hay un edificio {fila_salida, columna_salida}")
        elif salida in agua:
            print(f"Aqui hay un rio {fila_salida, columna_salida}")
        elif salida == entrada:
            print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
        else:
            print(f"Colocaste la salida en {fila_salida, columna_salida}")
            break

    obstaculo_opcional = []
    while True:
        obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
        if obstaculo == 1:
            fila = int(input("Dime la fila del obstaculo"))
            columna = int(input("Dime la columna del obstaculo"))
            obstaculo_agregado = (fila, columna)

            if not (0 <= fila < dimension and 0 <= columna < dimension):
                print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
            elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
                print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
            elif obstaculo_agregado in edificio:
                print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
            elif obstaculo_agregado in agua:
                print(f"No se puede agregar aqui ya que es un Rio {fila, columna}")
            elif obstaculo_agregado in obstaculo_opcional:
                print(f"Aqui ya agregaste un obstaculo!!!{fila, columna}")
            else:
                obstaculo_opcional.append(obstaculo_agregado)
                print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
        elif obstaculo == 2:
            break
        else:
            print("Opcion no valida favor lea las opciones e ingrese el numero")

    crear_ciudad(entrada, salida, edificio, agua, obstaculo_opcional, dimension)


if __name__ == "__main__":
    inicio_gps()
# Out:
# Colocaste la entrada en (0, 0)
# Colocaste la salida en (9, 9)
# Agregaste un obstaculo temporal en la posicion (6, 6)
# E . . . . . . . . .
# . # . . . . . . . .
# . . ~ . . . . . . .
# . . . ~ . . . . . .
# . . . . # . . . . .
# . . . . . . # . . .
# . . . . . . ! . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . S

# %%
def crear_ciudad(posicion_edificio, posicion_agua, dimension):
    ciudad = [["."for _ in range(dimension)]for _ in range(dimension)]

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "#"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "~"
        
    for filas in ciudad:
        print(" ".join(filas))
    return ciudad


# movimientos validos que puede realizar dentro del gps
def movimientos_validos(posicion_entrada, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    fila_entrada, columna_entrada = posicion_entrada
    movimientos_validos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila_entrada + direccion[0]
        nueva_columna = columna_entrada + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if(nueva_fila, nueva_columna) not in posicion_edificio:
                if(nueva_fila, nueva_columna) not in posicion_agua:
                    if(nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos_validos.append((nueva_fila, nueva_columna))
    return movimientos_validos


# configuracion inicial de los parametros del gps 
def inicio_gps():
    print("Bienvenido a la ciudad")
    dimension = int(input("Dime las cantidades de cuadras que quieres"))
    edificio = [(1, 1), (4, 4), (5, 6)]
    agua = [(2, 2), (3, 3)]
    crear_ciudad(edificio, agua, dimension)
    print("Configuremos tu destino")
    

    while True:
        fila_entrada = int(input("Dime la fila del punto de partida"))
        columna_entrada = int(input("Dime la columna del punto de partida"))
        entrada = (fila_entrada, columna_entrada)

        if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
        elif entrada in edificio:
            print(f"Aqui no puedes colocar, hay un edificio {fila_entrada, columna_entrada}")
        elif entrada in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_entrada, columna_entrada}")
        else:
            print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
            break

    while True:
        fila_salida = int(input("Dime la fila del punto de llegada"))
        columna_salida = int(input("Dime la columna del punto de llegada"))
        salida = (fila_salida, columna_salida)

        if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
        elif salida in edificio:
            print(f"Aqui no puede colocar, hay un edificio {fila_salida, columna_salida}")
        elif salida in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_salida, columna_salida}")
        elif salida == entrada:
            print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
        else:
            print(f"Colocaste la salida en {fila_salida, columna_salida}")
            break

    obstaculo_opcional = []
    while True:
        obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
        if obstaculo == 1:
            fila = int(input("Dime la fila del obstaculo"))
            columna = int(input("Dime la columna del obstaculo"))
            obstaculo_agregado = (fila, columna)

            if not (0 <= fila < dimension and 0 <= columna < dimension):
                print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
            elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
                print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
            elif obstaculo_agregado in edificio:
                print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
            elif obstaculo_agregado in agua:
                print(f"No se puede agregar aqui ya que es un Rio {fila, columna}")
            elif obstaculo_agregado in obstaculo_opcional:
                print(f"Aqui ya agregaste un obstaculo!!!{fila, columna}")
            else:
                obstaculo_opcional.append(obstaculo_agregado)
                print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
        elif obstaculo == 2:
            break
        else:
            print("Opcion no valida favor lea las opciones e ingrese el numero")

    actualizar_gps = crear_ciudad(edificio, agua, dimension)

    actualizar_gps[fila_entrada][columna_entrada] = "E"
    actualizar_gps[fila_salida][columna_salida] = "S"

    for (fila, columna) in obstaculo_opcional:
        actualizar_gps[fila][columna] = "!"

    for filas in actualizar_gps:
        print(" ".join(filas))


if __name__ == "__main__":
    inicio_gps()
# Out:
# Bienvenido a la ciudad
# . . . . . . . . . .
# . # . . . . . . . .
# . . ~ . . . . . . .
# . . . ~ . . . . . .
# . . . . # . . . . .
# . . . . . . # . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# Configuremos tu destino
# Colocaste la entrada en (0, 0)
# Colocaste la salida en (9, 9)
# . . . . . . . . . .
# . # . . . . . . . .
# . . ~ . . . . . . .
# . . . ~ . . . . . .
# . . . . # . . . . .
# . . . . . . # . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# E . . . . . . . . .
# . # . . . . . . . .
# . . ~ . . . . . . .
# . . . ~ . . . . . .
# . . . . # . . . . .
# . . . . . . # . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . S

# %%
# movimientos validos que puede realizar dentro del gps
def movimientos_validos(posicion_entrada, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    fila_entrada, columna_entrada = posicion_entrada
    movimientos_validos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila_entrada + direccion[0]
        nueva_columna = columna_entrada + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if(nueva_fila, nueva_columna) not in posicion_edificio:
                if(nueva_fila, nueva_columna) not in posicion_agua:
                    if(nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos_validos.append((nueva_fila, nueva_columna))
    return movimientos_validos

# %%
from collections import deque

def crear_ciudad(posicion_edificio, posicion_agua, dimension):
    ciudad = [["."for _ in range(dimension)]for _ in range(dimension)]

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "#"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "~"
        
    for filas in ciudad:
        print(" ".join(filas))
    return ciudad

def bfs_encontrar_camino(entrada, salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    """
    Implementa BFS para encontrar el camino más corto entre entrada y salida
    Retorna: lista de posiciones que forman el camino, o None si no hay camino
    """
    if entrada == salida:
        return [entrada]
    
    # Cola para BFS: cada elemento es (posicion_actual, camino_hasta_aqui)
    cola = deque([(entrada, [entrada])])
    visitados = {entrada}
    
    while cola:
        posicion_actual, camino_actual = cola.popleft()
        
        # Obtener todos los movimientos válidos desde la posición actual
        vecinos = movimientos_validos(posicion_actual, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension)
        
        for vecino in vecinos:
            if vecino == salida:
                # ¡Encontramos la salida!
                return camino_actual + [vecino]
            
            if vecino not in visitados:
                visitados.add(vecino)
                nuevo_camino = camino_actual + [vecino]
                cola.append((vecino, nuevo_camino))
    
    # No se encontró camino
    return None


def mostrar_ciudad_con_camino(ciudad, camino, entrada, salida):
    """Muestra la ciudad con el camino marcado"""
    # Crear una copia de la ciudad para no modificar la original
    ciudad_con_camino = [fila[:] for fila in ciudad]
    
    # Marcar el camino (excluyendo entrada y salida)
    for i, (fila, columna) in enumerate(camino):
        if i == 0:  # Entrada
            ciudad_con_camino[fila][columna] = "E"
        elif i == len(camino) - 1:  # Salida
            ciudad_con_camino[fila][columna] = "S"
        else:  # Camino intermedio
            ciudad_con_camino[fila][columna] = "*"
    
    print("\n=== CIUDAD CON CAMINO ENCONTRADO ===")
    for fila in ciudad_con_camino:
        print(" ".join(fila))
    print(f"\nCamino encontrado: {len(camino) - 1} pasos")
    print("Leyenda: E=Entrada, S=Salida, *=Camino, #=Edificio, ~=Agua, !=Obstáculo")



# configuracion inicial de los parametros del gps 
def inicio_gps():
    print("Bienvenido a la ciudad")
    dimension = 10
    edificio = [(1, 1), (4, 4), (5, 6)]
    agua = [(2, 2), (3, 3)]
    crear_ciudad(edificio, agua, dimension)
    print("Configuremos tu destino")
    

    while True:
        fila_entrada = int(input("Dime la fila del punto de partida"))
        columna_entrada = int(input("Dime la columna del punto de partida"))
        entrada = (fila_entrada, columna_entrada)

        if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
        elif entrada in edificio:
            print(f"Aqui no puedes colocar, hay un edificio {fila_entrada, columna_entrada}")
        elif entrada in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_entrada, columna_entrada}")
        else:
            print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
            break

    while True:
        fila_salida = int(input("Dime la fila del punto de llegada"))
        columna_salida = int(input("Dime la columna del punto de llegada"))
        salida = (fila_salida, columna_salida)

        if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
        elif salida in edificio:
            print(f"Aqui no puede colocar, hay un edificio {fila_salida, columna_salida}")
        elif salida in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_salida, columna_salida}")
        elif salida == entrada:
            print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
        else:
            print(f"Colocaste la salida en {fila_salida, columna_salida}")
            break

    obstaculo_opcional = []
    while True:
        obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
        if obstaculo == 1:
            fila = int(input("Dime la fila del obstaculo"))
            columna = int(input("Dime la columna del obstaculo"))
            obstaculo_agregado = (fila, columna)

            if not (0 <= fila < dimension and 0 <= columna < dimension):
                print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
            elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
                print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
            elif obstaculo_agregado in edificio:
                print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
            elif obstaculo_agregado in agua:
                print(f"No se puede agregar aqui ya que es un Rio {fila, columna}")
            elif obstaculo_agregado in obstaculo_opcional:
                print(f"Aqui ya agregaste un obstaculo!!!{fila, columna}")
            else:
                obstaculo_opcional.append(obstaculo_agregado)
                print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
        elif obstaculo == 2:
            break
        else:
            print("Opcion no valida favor lea las opciones e ingrese el numero")

    actualizar_gps = crear_ciudad(edificio, agua, dimension)

    actualizar_gps[fila_entrada][columna_entrada] = "E"
    actualizar_gps[fila_salida][columna_salida] = "S"

    for (fila, columna) in obstaculo_opcional:
        actualizar_gps[fila][columna] = "!"

    for filas in actualizar_gps:
        print(" ".join(filas))

    camino = bfs_encontrar_camino(entrada, salida, edificio, agua, obstaculo_opcional, dimension)
    
    if camino:
        print(f"Camino encontrado! ({len(camino) - 1} pasos)")
        mostrar_ciudad_con_camino(actualizar_gps, camino, entrada, salida)
        
        print(f"\nRuta paso a paso:")
        for i, (fila, columna) in enumerate(camino):
            if i == 0:
                print(f"  Paso {i}: INICIO en ({fila}, {columna})")
            elif i == len(camino) - 1:
                print(f"  Paso {i}: LLEGADA a ({fila}, {columna})")
            else:
                print(f"  Paso {i}: Moverse a ({fila}, {columna})")
    else:
        print("No se encontró un camino posible entre la entrada y la salida")
        print("Verifica que no haya obstáculos que bloqueen completamente el paso")



if __name__ == "__main__":
    inicio_gps()
# Out:
# Bienvenido a la ciudad
# . . . . . . . . . .
# . # . . . . . . . .
# . . ~ . . . . . . .
# . . . ~ . . . . . .
# . . . . # . . . . .
# . . . . . . # . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# Configuremos tu destino
# Colocaste la entrada en (0, 0)
# Colocaste la salida en (9, 9)
# Agregaste un obstaculo temporal en la posicion (9, 8)
# . . . . . . . . . .
# . # . . . . . . . .
# . . ~ . . . . . . .
# . . . ~ . . . . . .
# . . . . # . . . . .
# . . . . . . # . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# E . . . . . . . . .
# . # . . . . . . . .
# . . ~ . . . . . . .
# . . . ~ . . . . . .
# . . . . # . . . . .
# . . . . . . # . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . . .
# . . . . . . . . ! S
# Camino encontrado! (18 pasos)
#
# === CIUDAD CON CAMINO ENCONTRADO ===
# E . . . . . . . . .
# * # . . . . . . . .
# * . ~ . . . . . . .
# * . . ~ . . . . . .
# * . . . # . . . . .
# * . . . . . # . . .
# * . . . . . . . . .
# * . . . . . . . . .
# * * * * * * * * * *
# . . . . . . . . ! S
#
# Camino encontrado: 18 pasos
# Leyenda: E=Entrada, S=Salida, *=Camino, #=Edificio, ~=Agua, !=Obstáculo
#
# Ruta paso a paso:
#   Paso 0: INICIO en (0, 0)
#   Paso 1: Moverse a (1, 0)
#   Paso 2: Moverse a (2, 0)
#   Paso 3: Moverse a (3, 0)
#   Paso 4: Moverse a (4, 0)
#   Paso 5: Moverse a (5, 0)
#   Paso 6: Moverse a (6, 0)
#   Paso 7: Moverse a (7, 0)
#   Paso 8: Moverse a (8, 0)
#   Paso 9: Moverse a (8, 1)
#   Paso 10: Moverse a (8, 2)
#   Paso 11: Moverse a (8, 3)
#   Paso 12: Moverse a (8, 4)
#   Paso 13: Moverse a (8, 5)
#   Paso 14: Moverse a (8, 6)
#   Paso 15: Moverse a (8, 7)
#   Paso 16: Moverse a (8, 8)
#   Paso 17: Moverse a (8, 9)
#   Paso 18: LLEGADA a (9, 9)

# %%
import random
from collections import deque

def crear_ciudad_aleatoria(dimension, prob_edificio, prob_agua):
    """Crea una ciudad aleatoria con edificios y agua"""
    ciudad = []
    edificios = []
    aguas = []
    
    for fila in range(dimension):
        ciudad.append([])
        for columna in range(dimension):
            rand_num = random.randint(0, 100)

            if rand_num < prob_edificio:
                ciudad[fila].append("#")    # Edificio
                edificios.append((fila, columna))
            elif rand_num < prob_edificio + prob_agua:
                ciudad[fila].append("~")    # Agua
                aguas.append((fila, columna))
            else:
                ciudad[fila].append(".")    # Camino libre
    
    # Mostrar la ciudad generada
    for fila in ciudad:
        print(" ".join(fila))
    
    return ciudad, edificios, aguas

def movimientos_validos(posicion, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    """Calcula los movimientos válidos desde una posición"""
    fila, columna = posicion
    movimientos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila + direccion[0]
        nueva_columna = columna + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if (nueva_fila, nueva_columna) not in posicion_edificio:
                if (nueva_fila, nueva_columna) not in posicion_agua:
                    if (nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos.append((nueva_fila, nueva_columna))
    return movimientos

def bfs_encontrar_camino(entrada, salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    """
    Implementa BFS para encontrar el camino más corto entre entrada y salida
    Retorna: lista de posiciones que forman el camino, o None si no hay camino
    """
    if entrada == salida:
        return [entrada]
    
    # Cola para BFS: cada elemento es (posicion_actual, camino_hasta_aqui)
    cola = deque([(entrada, [entrada])])
    visitados = {entrada}
    
    while cola:
        posicion_actual, camino_actual = cola.popleft()
        
        # Obtener todos los movimientos válidos desde la posición actual
        vecinos = movimientos_validos(posicion_actual, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension)
        
        for vecino in vecinos:
            if vecino == salida:
                # ¡Encontramos la salida!
                return camino_actual + [vecino]
            
            if vecino not in visitados:
                visitados.add(vecino)
                nuevo_camino = camino_actual + [vecino]
                cola.append((vecino, nuevo_camino))
    
    # No se encontró camino
    return None

def mostrar_ciudad_con_camino(ciudad, camino, entrada, salida):
    """Muestra la ciudad con el camino marcado"""
    # Crear una copia de la ciudad para no modificar la original
    ciudad_con_camino = [fila[:] for fila in ciudad]
    
    # Marcar el camino (excluyendo entrada y salida)
    for i, (fila, columna) in enumerate(camino):
        if i == 0:  
            ciudad_con_camino[fila][columna] = "E"
        elif i == len(camino) - 1:  
            ciudad_con_camino[fila][columna] = "S"
        else: 
            ciudad_con_camino[fila][columna] = "*"
    
    for fila in ciudad_con_camino:
        print(" ".join(fila))

def inicio_gps():
    """Configuración inicial de los parámetros del GPS"""
    
    print("Bienvenido a la ciudad")
    dimension = int(input("Dime el tamaño de la ciudad que deseas: "))

    porcentaje_edificio = 30
    porcentaje_agua = 15
    
    print(f"\nGenerando ciudad de {dimension}x{dimension}...")
    print(f"Probabilidad de edificios: {porcentaje_edificio}%")
    print(f"Probabilidad de agua: {porcentaje_agua}%")
    
    ciudad, edificios, aguas = crear_ciudad_aleatoria(dimension, porcentaje_edificio, porcentaje_agua)
    
    print("\nConfiguremos tu destino")
    
    # Configurar punto de entrada
    while True:
        fila_entrada = int(input("Dime la fila del punto de partida: "))
        columna_entrada = int(input("Dime la columna del punto de partida: "))
        entrada = (fila_entrada, columna_entrada)

        if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
        elif entrada in edificios:
            print(f"Aqui no puedes colocar, hay un edificio {fila_entrada, columna_entrada}")
        elif entrada in aguas:
            print(f"Aqui no puedes colocar, hay agua {fila_entrada, columna_entrada}")
        else:
            print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
            break

    # Configurar punto de salida
    while True:
        fila_salida = int(input("Dime la fila del punto de llegada: "))
        columna_salida = int(input("Dime la columna del punto de llegada: "))
        salida = (fila_salida, columna_salida)

        if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
        elif salida in edificios:
            print(f"Aqui no puede colocar, hay un edificio {fila_salida, columna_salida}")
        elif salida in aguas:
            print(f"Aqui no puedes colocar, hay agua {fila_salida, columna_salida}")
        elif salida == entrada:
            print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
        else:
            print(f"Colocaste la salida en {fila_salida, columna_salida}")
            break

    # Configurar obstáculos opcionales
    obstaculo_opcional = []
    while True:
        obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir): "))
        if obstaculo == 1:
            fila = int(input("Dime la fila del obstaculo: "))
            columna = int(input("Dime la columna del obstaculo: "))
            obstaculo_agregado = (fila, columna)

            if not (0 <= fila < dimension and 0 <= columna < dimension):
                print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
            elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
                print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
            elif obstaculo_agregado in edificios:
                print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
            elif obstaculo_agregado in aguas:
                print(f"No se puede agregar aqui ya que hay agua {fila, columna}")
            elif obstaculo_agregado in obstaculo_opcional:
                print(f"Aqui ya agregaste un obstaculo!!! {fila, columna}")
            else:
                obstaculo_opcional.append(obstaculo_agregado)
                print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
        elif obstaculo == 2:
            break
        else:
            print("Opcion no valida favor lea las opciones e ingrese el numero")

    # Actualizar ciudad con entrada, salida y obstáculos
    ciudad[fila_entrada][columna_entrada] = "E"
    ciudad[fila_salida][columna_salida] = "S"

    for (fila, columna) in obstaculo_opcional:
        ciudad[fila][columna] = "!"

    print("\n=== CIUDAD CONFIGURADA ===")
    for fila in ciudad:
        print(" ".join(fila))

    # Buscar camino con BFS
    print("\nBuscando camino...")
    camino = bfs_encontrar_camino(entrada, salida, edificios, aguas, obstaculo_opcional, dimension)
    
    if camino:
        print(f"¡Camino encontrado! ({len(camino) - 1} pasos)")
        print("\n=== CIUDAD CON CAMINO ===")
        mostrar_ciudad_con_camino(ciudad, camino, entrada, salida)
    else:
        print("No se encontro el punto de llegada, verifique que no este bloqueado por obstaculos")

if __name__ == "__main__":
    inicio_gps()

# %%
from collections import deque

def crear_ciudad(posicion_edificio, posicion_agua, dimension):
    ciudad = [["."for _ in range(dimension)]for _ in range(dimension)]

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "#"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "~"
        
    for filas in ciudad:
        print(" ".join(filas))
    return ciudad

def bfs_encontrar_camino(entrada, salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    """
    Implementa BFS para encontrar el camino más corto entre entrada y salida
    Retorna: lista de posiciones que forman el camino, o None si no hay camino
    """
    if entrada == salida:
        return [entrada]
    
    # Cola para BFS: cada elemento es (posicion_actual, camino_hasta_aqui)
    cola = deque([(entrada, [entrada])])
    visitados = {entrada}
    
    while cola:
        posicion_actual, camino_actual = cola.popleft()
        
        # Obtener todos los movimientos válidos desde la posición actual
        vecinos = movimientos_validos(posicion_actual, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension)
        
        for vecino in vecinos:
            if vecino == salida:
                # ¡Encontramos la salida!
                return camino_actual + [vecino]
            
            if vecino not in visitados:
                visitados.add(vecino)
                nuevo_camino = camino_actual + [vecino]
                cola.append((vecino, nuevo_camino))
    
    # No se encontró camino
    return None


def mostrar_ciudad_con_camino(ciudad, camino, entrada, salida):
    """Muestra la ciudad con el camino marcado"""
    # Crear una copia de la ciudad para no modificar la original
    ciudad_con_camino = [fila[:] for fila in ciudad]
    
    # Marcar el camino (excluyendo entrada y salida)
    for i, (fila, columna) in enumerate(camino):
        if i == 0:  
            ciudad_con_camino[fila][columna] = "E"
        elif i == len(camino) - 1:  
            ciudad_con_camino[fila][columna] = "S"
        else: 
            ciudad_con_camino[fila][columna] = "*"
    
    for fila in ciudad_con_camino:
        print(" ".join(fila))


# configuracion inicial de los parametros del gps 
def inicio_gps():
    
    print("Bienvenido a la ciudad")
    dimension = 20
    edificio = [(1, 1), (4, 4), (5, 6)]
    agua = [(2, 2), (3, 3)]
    crear_ciudad(edificio, agua, dimension)
    print("Configuremos tu destino")
    

    while True:
        fila_entrada = int(input("Dime la fila del punto de partida"))
        columna_entrada = int(input("Dime la columna del punto de partida"))
        entrada = (fila_entrada, columna_entrada)

        if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
        elif entrada in edificio:
            print(f"Aqui no puedes colocar, hay un edificio {fila_entrada, columna_entrada}")
        elif entrada in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_entrada, columna_entrada}")
        else:
            print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
            break

    while True:
        fila_salida = int(input("Dime la fila del punto de llegada"))
        columna_salida = int(input("Dime la columna del punto de llegada"))
        salida = (fila_salida, columna_salida)

        if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
        elif salida in edificio:
            print(f"Aqui no puede colocar, hay un edificio {fila_salida, columna_salida}")
        elif salida in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_salida, columna_salida}")
        elif salida == entrada:
            print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
        else:
            print(f"Colocaste la salida en {fila_salida, columna_salida}")
            break

    obstaculo_opcional = []
    while True:
        obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
        if obstaculo == 1:
            fila = int(input("Dime la fila del obstaculo"))
            columna = int(input("Dime la columna del obstaculo"))
            obstaculo_agregado = (fila, columna)

            if not (0 <= fila < dimension and 0 <= columna < dimension):
                print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
            elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
                print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
            elif obstaculo_agregado in edificio:
                print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
            elif obstaculo_agregado in agua:
                print(f"No se puede agregar aqui ya que es un Rio {fila, columna}")
            elif obstaculo_agregado in obstaculo_opcional:
                print(f"Aqui ya agregaste un obstaculo!!!{fila, columna}")
            else:
                obstaculo_opcional.append(obstaculo_agregado)
                print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
        elif obstaculo == 2:
            break
        else:
            print("Opcion no valida favor lea las opciones e ingrese el numero")

    actualizar_gps = crear_ciudad(edificio, agua, dimension)

    actualizar_gps[fila_entrada][columna_entrada] = "E"
    actualizar_gps[fila_salida][columna_salida] = "S"

    for (fila, columna) in obstaculo_opcional:
        actualizar_gps[fila][columna] = "!"

    for filas in actualizar_gps:
        print(" ".join(filas))

    camino = bfs_encontrar_camino(entrada, salida, edificio, agua, obstaculo_opcional, dimension)
    
    if camino:
        print("Encontramos el camino")
        mostrar_ciudad_con_camino(actualizar_gps, camino, entrada, salida)

    else:
        print("No se encontro el punto de llegada, verifique que no este bloqueado por obstaculos")


if __name__ == "__main__":
    inicio_gps()
# Out:
# Bienvenido a la ciudad
# . . . . . . . . . . . . . . . . . . . .
# . # . . . . . . . . . . . . . . . . . .
# . . ~ . . . . . . . . . . . . . . . . .
# . . . ~ . . . . . . . . . . . . . . . .
# . . . . # . . . . . . . . . . . . . . .
# . . . . . . # . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . .
# Configuremos tu destino
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 157
#     153         print("No se encontro el punto de llegada, verifique que no este bloqueado por obstaculos")
#     156 if __name__ == "__main__":
# --> 157     inicio_gps()
#
# Cell In[48], line 78, in inicio_gps()
#      74 print("Configuremos tu destino")
#      77 while True:
# ---> 78     fila_entrada = int(input("Dime la fila del punto de partida"))
#      79     columna_entrada = int(input("Dime la columna del punto de partida"))
#      80     entrada = (fila_entrada, columna_entrada)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import random
from collections import deque

def crear_ciudad():
    for fila in range(dimension):
        ciudad.append([])
        for columna in range(dimension):
            rand_num = random.randint(0, 100)

            if rand_num < PROB_EDIFICIO:
                ciudad[fila].append("|#|")    # Edificio
                edificios.append((fila, columna))
            elif rand_num < PROB_EDIFICIO + PROB_AGUA:
                ciudad[fila].append("|~|")    # Agua
                aguas.append((fila, columna))
            else:
                ciudad[fila].append("|.|")    # Camino libre
        return ciudad
    
    for fila in ciudad:
        print(" ".join(fila))



def crear_ciudad(posicion_edificio, posicion_agua, dimension):
    ciudad = [["."for _ in range(dimension)]for _ in range(dimension)]

    for (fila, columna) in posicion_edificio:
        ciudad[fila][columna] = "#"

    for (fila, columna) in posicion_agua:
        ciudad[fila][columna] = "~"
        
    for filas in ciudad:
        print(" ".join(filas))
    return ciudad

def bfs_encontrar_camino(entrada, salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    """
    Implementa BFS para encontrar el camino más corto entre entrada y salida
    Retorna: lista de posiciones que forman el camino, o None si no hay camino
    """
    if entrada == salida:
        return [entrada]
    
    # Cola para BFS: cada elemento es (posicion_actual, camino_hasta_aqui)
    cola = deque([(entrada, [entrada])])
    visitados = {entrada}
    
    while cola:
        posicion_actual, camino_actual = cola.popleft()
        
        # Obtener todos los movimientos válidos desde la posición actual
        vecinos = movimientos_validos(posicion_actual, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension)
        
        for vecino in vecinos:
            if vecino == salida:
                # ¡Encontramos la salida!
                return camino_actual + [vecino]
            
            if vecino not in visitados:
                visitados.add(vecino)
                nuevo_camino = camino_actual + [vecino]
                cola.append((vecino, nuevo_camino))
    
    # No se encontró camino
    return None


def mostrar_ciudad_con_camino(ciudad, camino, entrada, salida):
    """Muestra la ciudad con el camino marcado"""
    # Crear una copia de la ciudad para no modificar la original
    ciudad_con_camino = [fila[:] for fila in ciudad]
    
    # Marcar el camino (excluyendo entrada y salida)
    for i, (fila, columna) in enumerate(camino):
        if i == 0:  
            ciudad_con_camino[fila][columna] = "E"
        elif i == len(camino) - 1:  
            ciudad_con_camino[fila][columna] = "S"
        else: 
            ciudad_con_camino[fila][columna] = "*"
    
    for fila in ciudad_con_camino:
        print(" ".join(fila))


# configuracion inicial de los parametros del gps 
def inicio_gps():
    
    print("Bienvenido a la ciudad")
    dimension = int(input("Dime el tamaño de la ciudad que deseas"))

    porcentaje_edificio = 30
    porcentaje_agua = 15
    ciudad = []
    edificios = []
    agua = []

    crear_ciudad()
    print("Configuremos tu destino")
    

    while True:
        fila_entrada = int(input("Dime la fila del punto de partida"))
        columna_entrada = int(input("Dime la columna del punto de partida"))
        entrada = (fila_entrada, columna_entrada)

        if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
        elif entrada in edificio:
            print(f"Aqui no puedes colocar, hay un edificio {fila_entrada, columna_entrada}")
        elif entrada in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_entrada, columna_entrada}")
        else:
            print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
            break

    while True:
        fila_salida = int(input("Dime la fila del punto de llegada"))
        columna_salida = int(input("Dime la columna del punto de llegada"))
        salida = (fila_salida, columna_salida)

        if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
        elif salida in edificio:
            print(f"Aqui no puede colocar, hay un edificio {fila_salida, columna_salida}")
        elif salida in agua:
            print(f"Aqui no puedes colocar, hay un rio {fila_salida, columna_salida}")
        elif salida == entrada:
            print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
        else:
            print(f"Colocaste la salida en {fila_salida, columna_salida}")
            break

    obstaculo_opcional = []
    while True:
        obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir)"))
        if obstaculo == 1:
            fila = int(input("Dime la fila del obstaculo"))
            columna = int(input("Dime la columna del obstaculo"))
            obstaculo_agregado = (fila, columna)

            if not (0 <= fila < dimension and 0 <= columna < dimension):
                print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
            elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
                print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
            elif obstaculo_agregado in edificio:
                print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
            elif obstaculo_agregado in agua:
                print(f"No se puede agregar aqui ya que es un Rio {fila, columna}")
            elif obstaculo_agregado in obstaculo_opcional:
                print(f"Aqui ya agregaste un obstaculo!!!{fila, columna}")
            else:
                obstaculo_opcional.append(obstaculo_agregado)
                print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
        elif obstaculo == 2:
            break
        else:
            print("Opcion no valida favor lea las opciones e ingrese el numero")

    actualizar_gps = crear_ciudad(edificio, agua, dimension)

    actualizar_gps[fila_entrada][columna_entrada] = "E"
    actualizar_gps[fila_salida][columna_salida] = "S"

    for (fila, columna) in obstaculo_opcional:
        actualizar_gps[fila][columna] = "!"

    for filas in actualizar_gps:
        print(" ".join(filas))

    camino = bfs_encontrar_camino(entrada, salida, edificio, agua, obstaculo_opcional, dimension)
    
    if camino:
        print("Encontramos el camino")
        mostrar_ciudad_con_camino(actualizar_gps, camino, entrada, salida)

    else:
        print("No se encontro el punto de llegada, verifique que no este bloqueado por obstaculos")


if __name__ == "__main__":
    inicio_gps()
# Out:
# Bienvenido a la ciudad
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 184
#     180         print("No se encontro el punto de llegada, verifique que no este bloqueado por obstaculos")
#     183 if __name__ == "__main__":
# --> 184     inicio_gps()
#
# Cell In[44], line 100, in inicio_gps()
#      97 edificios = []
#      98 agua = []
# --> 100 crear_ciudad()
#     101 print("Configuremos tu destino")
#     104 while True:
#
# TypeError: crear_ciudad() missing 3 required positional arguments: 'posicion_edificio', 'posicion_agua', and 'dimension'

# %%
import random
from collections import deque

def crear_ciudad_aleatoria(dimension, prob_edificio, prob_agua):
    """Crea una ciudad aleatoria con edificios y agua"""
    ciudad = []
    edificios = []
    aguas = []
    
    for fila in range(dimension):
        ciudad.append([])
        for columna in range(dimension):
            rand_num = random.randint(0, 100)

            if rand_num < prob_edificio:
                ciudad[fila].append("#")    # Edificio
                edificios.append((fila, columna))
            elif rand_num < prob_edificio + prob_agua:
                ciudad[fila].append("~")    # Agua
                aguas.append((fila, columna))
            else:
                ciudad[fila].append(".")    # Camino libre
    
    # Mostrar la ciudad generada
    for fila in ciudad:
        print(" ".join(fila))
    
    return ciudad, edificios, aguas

def movimientos_validos(posicion, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    """Calcula los movimientos válidos desde una posición"""
    fila, columna = posicion
    movimientos = []
    direcciones = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for direccion in direcciones:
        nueva_fila = fila + direccion[0]
        nueva_columna = columna + direccion[1]
        if 0 <= nueva_fila < dimension and 0 <= nueva_columna < dimension:
            if (nueva_fila, nueva_columna) not in posicion_edificio:
                if (nueva_fila, nueva_columna) not in posicion_agua:
                    if (nueva_fila, nueva_columna) not in posicion_obstaculo_opcional:
                        movimientos.append((nueva_fila, nueva_columna))
    return movimientos

def bfs_encontrar_camino(entrada, salida, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension):
    """
    Implementa BFS para encontrar el camino más corto entre entrada y salida
    Retorna: lista de posiciones que forman el camino, o None si no hay camino
    """
    if entrada == salida:
        return [entrada]
    
    # Cola para BFS: cada elemento es (posicion_actual, camino_hasta_aqui)
    cola = deque([(entrada, [entrada])])
    visitados = {entrada}
    
    while cola:
        posicion_actual, camino_actual = cola.popleft()
        
        # Obtener todos los movimientos válidos desde la posición actual
        vecinos = movimientos_validos(posicion_actual, posicion_edificio, posicion_agua, posicion_obstaculo_opcional, dimension)
        
        for vecino in vecinos:
            if vecino == salida:
                # ¡Encontramos la salida!
                return camino_actual + [vecino]
            
            if vecino not in visitados:
                visitados.add(vecino)
                nuevo_camino = camino_actual + [vecino]
                cola.append((vecino, nuevo_camino))
    
    # No se encontró camino
    return None

def mostrar_ciudad_con_camino(ciudad, camino, entrada, salida):
    """Muestra la ciudad con el camino marcado"""
    # Crear una copia de la ciudad para no modificar la original
    ciudad_con_camino = [fila[:] for fila in ciudad]
    
    # Marcar el camino (excluyendo entrada y salida)
    for i, (fila, columna) in enumerate(camino):
        if i == 0:  
            ciudad_con_camino[fila][columna] = "E"
        elif i == len(camino) - 1:  
            ciudad_con_camino[fila][columna] = "S"
        else: 
            ciudad_con_camino[fila][columna] = "*"
    
    for fila in ciudad_con_camino:
        print(" ".join(fila))

def inicio_gps():
    """Configuración inicial de los parámetros del GPS"""
    
    print("Bienvenido a la ciudad")
    dimension = int(input("Dime el tamaño de la ciudad que deseas: "))

    porcentaje_edificio = 30
    porcentaje_agua = 15
    
    print(f"\nGenerando ciudad de {dimension}x{dimension}...")
    print(f"Probabilidad de edificios: {porcentaje_edificio}%")
    print(f"Probabilidad de agua: {porcentaje_agua}%")
    
    ciudad, edificios, aguas = crear_ciudad_aleatoria(dimension, porcentaje_edificio, porcentaje_agua)
    
    print("\nConfiguremos tu destino")
    
    # Configurar punto de entrada
    while True:
        fila_entrada = int(input("Dime la fila del punto de partida: "))
        columna_entrada = int(input("Dime la columna del punto de partida: "))
        entrada = (fila_entrada, columna_entrada)

        if not (0 <= fila_entrada < dimension and 0 <= columna_entrada < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_entrada, columna_entrada}")
        elif entrada in edificios:
            print(f"Aqui no puedes colocar, hay un edificio {fila_entrada, columna_entrada}")
        elif entrada in aguas:
            print(f"Aqui no puedes colocar, hay agua {fila_entrada, columna_entrada}")
        else:
            print(f"Colocaste la entrada en {fila_entrada, columna_entrada}")
            break

    # Configurar punto de salida
    while True:
        fila_salida = int(input("Dime la fila del punto de llegada: "))
        columna_salida = int(input("Dime la columna del punto de llegada: "))
        salida = (fila_salida, columna_salida)

        if not (0 <= fila_salida < dimension and 0 <= columna_salida < dimension):
            print(f"Este punto esta fuera de los limites de la ciudad {fila_salida, columna_salida}")
        elif salida in edificios:
            print(f"Aqui no puede colocar, hay un edificio {fila_salida, columna_salida}")
        elif salida in aguas:
            print(f"Aqui no puedes colocar, hay agua {fila_salida, columna_salida}")
        elif salida == entrada:
            print(f"Estas colocando en el mismo punto de inicio {fila_salida, columna_salida}")
        else:
            print(f"Colocaste la salida en {fila_salida, columna_salida}")
            break

    # Configurar obstáculos opcionales
    obstaculo_opcional = []
    while True:
        obstaculo = int(input("Ingrese el numero de la opcion que desea 1- Quiero ingresar un obstaculo 2- No deseo agregar nada(Salir): "))
        if obstaculo == 1:
            fila = int(input("Dime la fila del obstaculo: "))
            columna = int(input("Dime la columna del obstaculo: "))
            obstaculo_agregado = (fila, columna)

            if not (0 <= fila < dimension and 0 <= columna < dimension):
                print(f"Esta posicion no es valida ya que esta fuera de la ciudad {fila, columna}")
            elif obstaculo_agregado == entrada or obstaculo_agregado == salida:
                print(f"No se puede agregar obstaculo ya que esta en el punto de Partida/Llegada ({fila, columna})")
            elif obstaculo_agregado in edificios:
                print(f"No se puede agregar aqui ya que es un Edificio {fila, columna}")
            elif obstaculo_agregado in aguas:
                print(f"No se puede agregar aqui ya que hay agua {fila, columna}")
            elif obstaculo_agregado in obstaculo_opcional:
                print(f"Aqui ya agregaste un obstaculo!!! {fila, columna}")
            else:
                obstaculo_opcional.append(obstaculo_agregado)
                print(f"Agregaste un obstaculo temporal en la posicion {fila, columna}")
        elif obstaculo == 2:
            break
        else:
            print("Opcion no valida favor lea las opciones e ingrese el numero")

    # Actualizar ciudad con entrada, salida y obstáculos
    ciudad[fila_entrada][columna_entrada] = "E"
    ciudad[fila_salida][columna_salida] = "S"

    for (fila, columna) in obstaculo_opcional:
        ciudad[fila][columna] = "!"

    print("\n=== CIUDAD CONFIGURADA ===")
    for fila in ciudad:
        print(" ".join(fila))

    # Buscar camino con BFS
    print("\nBuscando camino...")
    camino = bfs_encontrar_camino(entrada, salida, edificios, aguas, obstaculo_opcional, dimension)
    
    if camino:
        print(f"¡Camino encontrado! ({len(camino) - 1} pasos)")
        print("\n=== CIUDAD CON CAMINO ===")
        mostrar_ciudad_con_camino(ciudad, camino, entrada, salida)
    else:
        print("No se encontro el punto de llegada, verifique que no este bloqueado por obstaculos")

if __name__ == "__main__":
    inicio_gps()

# %%
# Porcentaje de elementos en el mapa
PROB_EDIFICIO = 35  # 15%
PROB_AGUA = 15      # 10%

ciudad = []
edificios = []
aguas = []
for fila in range(dimension):
    ciudad.append([])
    for columna in range(dimension):
        rand_num = random.randint(0, 100)

        if rand_num < PROB_EDIFICIO:
            ciudad[fila].append("|#|")    # Edificio
            edificios.append((fila, columna))
        elif rand_num < PROB_EDIFICIO + PROB_AGUA:
            ciudad[fila].append("|~|")    # Agua
            aguas.append((fila, columna))
        else:
            ciudad[fila].append("|.|")    # Camino libre

# %%
dimension = int(input("Dime el tamaño de la ciudad: "))
edificio = '#'

def crear_ciudad(dimension, edificio):
    matriz = [['.' for _ in range(dimension)] for _ in range(dimension)]

    for i in range(dimension):
        for j in range(0, dimension, 2):
            if i % 2 == 0:  # Solo en filas pares
                matriz[i][j] = edificio

    for fila in matriz:
        print(' '.join(fila))
    return matriz

crear_ciudad(dimension, edificio)
# Out:
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# [['#', '.', '#', '.', '#', '.', '#', '.', '#', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['#', '.', '#', '.', '#', '.', '#', '.', '#', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['#', '.', '#', '.', '#', '.', '#', '.', '#', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['#', '.', '#', '.', '#', '.', '#', '.', '#', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['#', '.', '#', '.', '#', '.', '#', '.', '#', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.']]

# %%
import random

dimension = int(input("Dime el tamaño de la ciudad: "))
edificio = '#'
agua = '~'
porcentaje_agua = 3  # 15% de probabilidad de agua en celdas no edificio

def crear_ciudad(dimension, edificio, agua):
    # Crear matriz base
    matriz = [['.' for _ in range(dimension)] for _ in range(dimension)]
    posiciones_agua = []
    
    # Primero colocamos los edificios en su patrón fijo
    for i in range(0, dimension, 2):
        for j in range(0, dimension, 2):
            matriz[i][j] = edificio
    
    # Luego agregamos agua aleatoriamente en las celdas vacías
    for i in range(dimension):
        for j in range(dimension):
            # Solo considerar celdas vacías (no edificios)
            if matriz[i][j] == '.':
                if random.randint(1, 100) <= porcentaje_agua:
                    matriz[i][j] = agua
                    posiciones_agua.append((i, j))
    
    return matriz, posiciones_agua

# Generar y mostrar la ciudad
ciudad, aguas = crear_ciudad(dimension, edificio, agua)
for fila in ciudad:
    print(' '.join(fila))
# Out:
# # . # . # . # . # ~
# . ~ . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # ~ # . # . # .
# . . . . . . . . . .

# %%
import random

dimension = int(input("Dime el tamaño de la ciudad: "))
edificio = '#'
agua = '~'
porcentaje_agua = 5 

def crear_ciudad_exacta(dimension, edificio, agua):
    matriz = [['.' for _ in range(dimension)] for _ in range(dimension)]
    celdas_vacias = []
    
    # Colocar edificios y recolectar celdas vacías
    for i in range(dimension):
        for j in range(dimension):
            if i % 2 == 0 and j % 2 == 0:
                matriz[i][j] = edificio
            else:
                celdas_vacias.append((i, j))
    
    # Calcular número exacto de celdas de agua (15%)
    num_aguas = int(len(celdas_vacias) * porcentaje_agua / 100)
    posiciones_agua = random.sample(celdas_vacias, num_aguas)
    
    # Colocar el agua
    for i, j in posiciones_agua:
        matriz[i][j] = agua
    
    return matriz, posiciones_agua

ciudad, aguas = crear_ciudad(dimension, edificio, agua)
for fila in ciudad:
    print(' '.join(fila))
# Out:
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # ~ # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .

# %%
import random
dimension = int(input("Dime el tamaño de la ciudad"))
edificio = '#'
agua = "~"
porcentaje_agua = 4

def crear_ciudad(dimension, edificio, agua):
    matriz = [['.' for _ in range(dimension)] for _ in range(dimension)]
    posicion_agua = []

    for fila in range(0, dimension, 2):
        for columna in range(0, dimension, 2):
            matriz[fila][columna] = edificio
    
    for fila in range(dimension):
        for columna in range(dimension):
            if matriz[fila][columna] == ".":
                if random.randint(0, 100) <= porcentaje_agua:
                    matriz[fila][columna] = agua
                    posicion_agua.append((fila, columna))
    return matriz, posicion_agua

def imprimir_ciudad():
    ciudad = crear_ciudad(dimension, edificio, agua)
    for fila in ciudad:
        print(' '.join(fila))

imprimir_ciudad()
# mostrar = crear_ciudad(dimension, edificio, agua)
# for fila in mostrar:
#     print(' '.join(fila))
# Out:
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . . .
# # . # . # . # . # .
# . . . . . . . . ~ .
# # . # . # . # . # .
# . . . . . . . ~ . .
# # . # . # . # . # .
# . ~ ~ . . . . . . .
